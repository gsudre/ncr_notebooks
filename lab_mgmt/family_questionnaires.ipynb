# %% [markdown]
# ** 02/02/2018 **
#
# I just noticed that some questionnaires that should be applied to all members of the family, like the CAARS and FES, are only there for one of the kids. That creates holes in queries that look for the kid without the questionnaires assigned. Let's first identify which kids need the form copied.
#
# We're going to use the results of the Max Form query Labmatrix created for us, augmented by the nuclear family ID information. This will give us an idea of which kids need it, but all forms for that kid will need to be copied to the other kid, not just the shown date, as that's just the latest date.

# %%
import pandas as pd
import numpy as np

cnt = 0
df = pd.read_excel('/Users/sudregp/data_plugging/max_dates_02012018.xlsx')
for fam in np.unique(df['Nuclear ID']):
    fam_df = df[df['Nuclear ID'] == fam]
    num_nans = np.sum(pd.isnull(fam_df['CAARS Self Report']))
    if num_nans > 0 and num_nans< fam_df.shape[0]:
        print 'Family %d has less CAARS than total number of members ' % fam + \
              '(%d / %d)' % (num_nans, fam_df.shape[0])
        cnt += 1
print 'Total: %d families' % cnt
# Out:
# Family 8 has less CAARS than total number of members (3 / 4)
# Family 36 has less CAARS than total number of members (4 / 5)
# Family 53 has less CAARS than total number of members (1 / 2)
# Family 288 has less CAARS than total number of members (3 / 4)
# Family 374 has less CAARS than total number of members (1 / 2)
# Family 385 has less CAARS than total number of members (1 / 7)
# Family 471 has less CAARS than total number of members (2 / 5)
# Family 515 has less CAARS than total number of members (1 / 2)
# Family 528 has less CAARS than total number of members (1 / 2)
# Family 698 has less CAARS than total number of members (1 / 7)
# Family 727 has less CAARS than total number of members (1 / 2)
# Family 735 has less CAARS than total number of members (1 / 2)
# Family 855 has less CAARS than total number of members (1 / 4)
# Family 871 has less CAARS than total number of members (1 / 6)
# Family 1334 has less CAARS than total number of members (2 / 3)
# Family 1673 has less CAARS than total number of members (2 / 3)
# Family 1683 has less CAARS than total number of members (1 / 2)
# Family 1697 has less CAARS than total number of members (3 / 5)
# Family 1731 has less CAARS than total number of members (1 / 2)
# Family 1739 has less CAARS than total number of members (1 / 2)
# Family 1743 has less CAARS than total number of members (1 / 2)
# Family 1747 has less CAARS than total number of members (1 / 2)
# Family 1753 has less CAARS than total number of members (1 / 2)
# Family 1756 has less CAARS than total number of members (1 / 2)
# Family 1774 has less CAARS than total number of members (1 / 3)
# Family 1855 has less CAARS than total number of members (1 / 2)
# Family 1892 has less CAARS than total number of members (2 / 4)
# Family 1893 has less CAARS than total number of members (1 / 4)
# Family 1894 has less CAARS than total number of members (4 / 5)
# Family 1899 has less CAARS than total number of members (2 / 5)
# Family 1976 has less CAARS than total number of members (4 / 5)
# Family 1988 has less CAARS than total number of members (1 / 2)
# Family 10009 has less CAARS than total number of members (5 / 6)
# Family 10018 has less CAARS than total number of members (2 / 3)
# Family 10033 has less CAARS than total number of members (1 / 4)
# Family 10047 has less CAARS than total number of members (2 / 3)
# Family 10049 has less CAARS than total number of members (1 / 2)
# Family 10059 has less CAARS than total number of members (3 / 4)
# Family 10077 has less CAARS than total number of members (1 / 2)
# Family 10084 has less CAARS than total number of members (1 / 2)
# Family 10090 has less CAARS than total number of members (3 / 4)
# Family 10094 has less CAARS than total number of members (1 / 4)
# Family 10109 has less CAARS than total number of members (2 / 3)
# Family 10131 has less CAARS than total number of members (5 / 6)
# Family 10136 has less CAARS than total number of members (1 / 2)
# Family 10139 has less CAARS than total number of members (1 / 2)
# Family 10153 has less CAARS than total number of members (3 / 5)
# Family 10156 has less CAARS than total number of members (2 / 3)
# Family 10164 has less CAARS than total number of members (3 / 4)
# Family 10171 has less CAARS than total number of members (1 / 2)
# Family 10177 has less CAARS than total number of members (1 / 2)
# Family 10182 has less CAARS than total number of members (4 / 5)
# Family 10189 has less CAARS than total number of members (1 / 2)
# Family 10199 has less CAARS than total number of members (1 / 2)
# Family 10203 has less CAARS than total number of members (2 / 3)
# Family 10209 has less CAARS than total number of members (1 / 3)
# Family 10215 has less CAARS than total number of members (5 / 6)
# Family 10221 has less CAARS than total number of members (1 / 2)
# Family 10227 has less CAARS than total number of members (1 / 2)
# Family 10232 has less CAARS than total number of members (1 / 2)
# Family 10247 has less CAARS than total number of members (1 / 2)
# Family 10253 has less CAARS than total number of members (1 / 2)
# Family 10275 has less CAARS than total number of members (7 / 8)
# Family 10277 has less CAARS than total number of members (3 / 4)
# Family 10287 has less CAARS than total number of members (1 / 4)
# Family 10295 has less CAARS than total number of members (1 / 2)
# Family 10296 has less CAARS than total number of members (2 / 3)
# Family 10299 has less CAARS than total number of members (2 / 5)
# Family 10305 has less CAARS than total number of members (3 / 4)
# Family 10308 has less CAARS than total number of members (1 / 5)
# Family 10318 has less CAARS than total number of members (3 / 5)
# Family 10319 has less CAARS than total number of members (1 / 2)
# Family 10337 has less CAARS than total number of members (1 / 4)
# Family 10338 has less CAARS than total number of members (1 / 2)
# Family 10347 has less CAARS than total number of members (4 / 5)
# Family 10352 has less CAARS than total number of members (1 / 4)
# Family 10360 has less CAARS than total number of members (1 / 2)
# Family 10364 has less CAARS than total number of members (1 / 3)
# Family 10366 has less CAARS than total number of members (1 / 2)
# Family 10370 has less CAARS than total number of members (1 / 2)
# Family 10395 has less CAARS than total number of members (2 / 4)
# Family 10396 has less CAARS than total number of members (1 / 5)
# Family 10397 has less CAARS than total number of members (1 / 3)
# Family 10398 has less CAARS than total number of members (1 / 5)
# Family 10399 has less CAARS than total number of members (3 / 5)
# Family 10401 has less CAARS than total number of members (2 / 3)
# Family 10410 has less CAARS than total number of members (3 / 5)
# Family 10412 has less CAARS than total number of members (2 / 4)
# Family 10430 has less CAARS than total number of members (3 / 5)
# Family 10433 has less CAARS than total number of members (1 / 2)
# Family 10435 has less CAARS than total number of members (2 / 3)
# Family 10436 has less CAARS than total number of members (2 / 4)
# Family 10440 has less CAARS than total number of members (1 / 2)
# Family 10442 has less CAARS than total number of members (1 / 2)
# Family 10448 has less CAARS than total number of members (2 / 4)
# Family 10449 has less CAARS than total number of members (1 / 2)
# Family 10450 has less CAARS than total number of members (1 / 2)
# Family 10451 has less CAARS than total number of members (1 / 2)
# Family 10452 has less CAARS than total number of members (1 / 2)
# Family 10453 has less CAARS than total number of members (1 / 2)
# Family 10454 has less CAARS than total number of members (1 / 2)
# Family 10455 has less CAARS than total number of members (1 / 2)
# Family 10457 has less CAARS than total number of members (1 / 4)
# Family 10471 has less CAARS than total number of members (1 / 2)
# Family 10472 has less CAARS than total number of members (2 / 6)
# Family 10474 has less CAARS than total number of members (1 / 3)
# Family 10475 has less CAARS than total number of members (2 / 3)
# Family 10478 has less CAARS than total number of members (1 / 6)
# Family 10481 has less CAARS than total number of members (1 / 5)
# Family 10482 has less CAARS than total number of members (3 / 5)
# Family 10483 has less CAARS than total number of members (3 / 4)
# Family 10502 has less CAARS than total number of members (1 / 4)
# Total: 112 families

# %% [markdown]
# OK, now we need to check which ones involve kids:

# %%
fam_cnt = 0
kid_cnt = 0
df = pd.read_excel('/Users/sudregp/data_plugging/max_dates_02012018.xlsx')
for fam in np.unique(df['Nuclear ID']):
    fam_df = df[df['Nuclear ID'] == fam]
    num_nans = np.sum(pd.isnull(fam_df['CAARS Self Report']))
    num_caars = np.sum(~pd.isnull(fam_df['CAARS Self Report']))
    num_fam = fam_df.shape[0]
    # have less questionnaire dates than the number of family members?
    if num_nans > 0 and num_nans < num_fam:
        # check everybody's age at the time of the first tests
        q_date = pd.Timestamp(fam_df['CAARS Self Report'].dropna().min())
        fam_ages = [q_date - pd.Timestamp(d) for d in fam_df['Date of Birth']]
        num_kids = 0
        for a in fam_ages:
            if a.days/365 < 18:
                num_kids += 1
        if num_kids > 1 and num_kids > num_caars:
            print 'Family %d has %d kids but only %d CAARS.' % (fam,
                                                                num_kids,
                                                                num_caars)
            fam_cnt += 1
            kid_cnt += (num_kids - num_caars)
print 'Total: %d families, %d kids' % (fam_cnt, kid_cnt)
# Out:
# Family 288 has 2 kids but only 1 CAARS.
# Family 1334 has 3 kids but only 1 CAARS.
# Family 1673 has 3 kids but only 1 CAARS.
# Family 1683 has 2 kids but only 1 CAARS.
# Family 1697 has 3 kids but only 2 CAARS.
# Family 1731 has 2 kids but only 1 CAARS.
# Family 1743 has 2 kids but only 1 CAARS.
# Family 1747 has 2 kids but only 1 CAARS.
# Family 1753 has 2 kids but only 1 CAARS.
# Family 1756 has 2 kids but only 1 CAARS.
# Family 1774 has 3 kids but only 2 CAARS.
# Family 1855 has 2 kids but only 1 CAARS.
# Family 1894 has 3 kids but only 1 CAARS.
# Family 1976 has 3 kids but only 1 CAARS.
# Family 1988 has 2 kids but only 1 CAARS.
# Family 10009 has 4 kids but only 1 CAARS.
# Family 10018 has 3 kids but only 1 CAARS.
# Family 10047 has 3 kids but only 1 CAARS.
# Family 10049 has 2 kids but only 1 CAARS.
# Family 10077 has 2 kids but only 1 CAARS.
# Family 10084 has 2 kids but only 1 CAARS.
# Family 10090 has 2 kids but only 1 CAARS.
# Family 10109 has 2 kids but only 1 CAARS.
# Family 10131 has 4 kids but only 1 CAARS.
# Family 10139 has 2 kids but only 1 CAARS.
# Family 10153 has 3 kids but only 2 CAARS.
# Family 10156 has 3 kids but only 1 CAARS.
# Family 10164 has 2 kids but only 1 CAARS.
# Family 10171 has 2 kids but only 1 CAARS.
# Family 10177 has 2 kids but only 1 CAARS.
# Family 10182 has 3 kids but only 1 CAARS.
# Family 10189 has 2 kids but only 1 CAARS.
# Family 10199 has 2 kids but only 1 CAARS.
# Family 10203 has 3 kids but only 1 CAARS.
# Family 10215 has 4 kids but only 1 CAARS.
# Family 10221 has 2 kids but only 1 CAARS.
# Family 10227 has 2 kids but only 1 CAARS.
# Family 10232 has 2 kids but only 1 CAARS.
# Family 10247 has 2 kids but only 1 CAARS.
# Family 10253 has 2 kids but only 1 CAARS.
# Family 10275 has 4 kids but only 1 CAARS.
# Family 10277 has 2 kids but only 1 CAARS.
# Family 10318 has 3 kids but only 2 CAARS.
# Family 10337 has 4 kids but only 3 CAARS.
# Family 10338 has 2 kids but only 1 CAARS.
# Family 10347 has 3 kids but only 1 CAARS.
# Family 10366 has 2 kids but only 1 CAARS.
# Family 10397 has 3 kids but only 2 CAARS.
# Family 10399 has 3 kids but only 2 CAARS.
# Family 10401 has 2 kids but only 1 CAARS.
# Family 10410 has 3 kids but only 2 CAARS.
# Family 10430 has 3 kids but only 2 CAARS.
# Family 10475 has 2 kids but only 1 CAARS.
# Family 10483 has 2 kids but only 1 CAARS.
# Total: 54 families, 72 kids

# %% [markdown]
# OK, this could give us some more data. How does it look for FES?

# %%
fam_cnt = 0
kid_cnt = 0
df = pd.read_excel('/Users/sudregp/data_plugging/max_dates_02012018.xlsx')
for fam in np.unique(df['Nuclear ID']):
    fam_df = df[df['Nuclear ID'] == fam]
    num_nans = np.sum(pd.isnull(fam_df['Family Enviro Scale']))
    num_caars = np.sum(~pd.isnull(fam_df['Family Enviro Scale']))
    num_fam = fam_df.shape[0]
    # have less questionnaire dates than the number of family members?
    if num_nans > 0 and num_nans < num_fam:
        # check everybody's age at the time of the first tests
        q_date = pd.Timestamp(fam_df['Family Enviro Scale'].dropna().min())
        fam_ages = [q_date - pd.Timestamp(d) for d in fam_df['Date of Birth']]
        num_kids = 0
        for a in fam_ages:
            if a.days/365 < 18:
                num_kids += 1
        if num_kids > 1 and num_kids > num_caars:
            print 'Family %d has %d kids but only %d FES.' % (fam,
                                                                num_kids,
                                                                num_caars)
            fam_cnt += 1
            kid_cnt += (num_kids - num_caars)
print 'Total: %d families, %d kids' % (fam_cnt, kid_cnt)
# Out:
# Family 1010 has 2 kids but only 1 FES.
# Family 1334 has 3 kids but only 1 FES.
# Family 1673 has 3 kids but only 2 FES.
# Family 1683 has 2 kids but only 1 FES.
# Family 1687 has 2 kids but only 1 FES.
# Family 1697 has 2 kids but only 1 FES.
# Family 1735 has 2 kids but only 1 FES.
# Family 1743 has 2 kids but only 1 FES.
# Family 1747 has 2 kids but only 1 FES.
# Family 1753 has 2 kids but only 1 FES.
# Family 1764 has 2 kids but only 1 FES.
# Family 1774 has 3 kids but only 2 FES.
# Family 1854 has 2 kids but only 1 FES.
# Family 1855 has 2 kids but only 1 FES.
# Family 1892 has 2 kids but only 1 FES.
# Family 1895 has 2 kids but only 1 FES.
# Family 1899 has 2 kids but only 1 FES.
# Family 10002 has 2 kids but only 1 FES.
# Family 10004 has 2 kids but only 1 FES.
# Family 10018 has 3 kids but only 2 FES.
# Family 10020 has 2 kids but only 1 FES.
# Family 10041 has 2 kids but only 1 FES.
# Family 10049 has 2 kids but only 1 FES.
# Family 10059 has 2 kids but only 1 FES.
# Family 10077 has 2 kids but only 1 FES.
# Family 10094 has 2 kids but only 1 FES.
# Family 10109 has 2 kids but only 1 FES.
# Family 10131 has 4 kids but only 1 FES.
# Family 10139 has 2 kids but only 1 FES.
# Family 10153 has 3 kids but only 1 FES.
# Family 10156 has 3 kids but only 1 FES.
# Family 10160 has 2 kids but only 1 FES.
# Family 10171 has 2 kids but only 1 FES.
# Family 10173 has 2 kids but only 1 FES.
# Family 10177 has 2 kids but only 1 FES.
# Family 10178 has 2 kids but only 1 FES.
# Family 10182 has 3 kids but only 1 FES.
# Family 10189 has 2 kids but only 1 FES.
# Family 10197 has 2 kids but only 1 FES.
# Family 10203 has 3 kids but only 1 FES.
# Family 10216 has 2 kids but only 1 FES.
# Family 10232 has 2 kids but only 1 FES.
# Family 10253 has 2 kids but only 1 FES.
# Family 10279 has 2 kids but only 1 FES.
# Family 10299 has 2 kids but only 1 FES.
# Family 10318 has 3 kids but only 2 FES.
# Family 10338 has 2 kids but only 1 FES.
# Family 10347 has 3 kids but only 1 FES.
# Family 10387 has 2 kids but only 1 FES.
# Family 10395 has 2 kids but only 1 FES.
# Family 10397 has 3 kids but only 2 FES.
# Family 10399 has 3 kids but only 2 FES.
# Family 10401 has 2 kids but only 1 FES.
# Family 10405 has 3 kids but only 1 FES.
# Family 10472 has 2 kids but only 1 FES.
# Family 10475 has 2 kids but only 1 FES.
# Family 10506 has 2 kids but only 1 FES.
# Total: 57 families, 66 kids

# %% [markdown]
# Sent Wendy a secure e-mail to add nuclear IDs to people that have none in the spreadsheet, and asked Labmatrix how to best proceed to populate those kids.
